# %% [markdown]
# # **Implementación de los casos de 3 Qubits**

# %%
# %load_ext autoreload
# %autoreload 2

from modules import schnorr_lattice as sl
from modules import qaoa as q
from modules import utils

import numpy as np
import matplotlib.pyplot as plt
from qiskit.visualization import plot_histogram

# %%
seed = 42

# %%
N3 = 1961

# %%
threeQubit = sl.schnorrCVP(N3, 1.5, 1, seed)
# Out:
# El numero de bits de N = 1961 es m = 11
# La dimension del reticulo que vamos a tratar es n = 3
# La cota smooth que vamos a tomar: 18

# %% [markdown]
# ## **1. Algoritmo de Schnorr**

# %%
cvpInstance = threeQubit.generate_cvp(10)
# Out:
# B =
# [ 1 0 0 22 ]
# [ 0 1 0 35 ]
# [ 0 0 2 51 ]
# t =
# (0, 0, 0, 240)

# %%
D3 = threeQubit.lll_reduced(cvpInstance.B, delta = 0.75)
print(f'D3 = \n{D3}')
# Out:
# D3 =
# [  1 -2 2  3 ]
# [ -4  1 2 -2 ]
# [ -3  2 0  4 ]

# %%
cvpResult = threeQubit.babai_algorithm(cvpInstance, delta = 0.75)
print(f'D3 = \n{cvpResult.D}\n')
print(f'b_op3 = \n{cvpResult.b_op}\n')
print(f'res_vector3 = \n{cvpResult.res_vector}\n')
print(f'step_sign3 = \n{cvpResult.step_sign}\n')
print(f'w3 = \n{cvpResult.weight}\n')
# Out:
# D3 =
# [  1 -2 2  3 ]
# [ -4  1 2 -2 ]
# [ -3  2 0  4 ]
#
# b_op3 =
# [  0   4   4 242]
#
# res_vector3 =
# [ 0 -4 -4 -2]
#
# step_sign3 =
# [-1 -1 -1]
#
# w3 =
# (22, -20, 34)

# %% [markdown]
# ## **2. Algoritmo QAOA**

# %%
qubo3 = q.define_qubo(cvpResult.D, cvpResult.res_vector, cvpResult.step_sign, threeQubit.get_n())

print(qubo3.prettyprint())
# Out:
# Problem name: quboProblem
#
# Minimize
#   18*z_0^2 - 16*z_0*z_1 + 10*z_0*z_2 + 25*z_1^2 + 12*z_1*z_2 + 29*z_2^2 - 12*z_0
#   - 16*z_1 - 32*z_2 + 36
#
# Subject to
#   No constraints
#
#   Binary variables (3)
#     z_0 z_1 z_2

# %%
Hc3, offset3 = q.define_hamiltonian(qubo3)

print("Offset = {}\n".format(offset3))
print("Hamiltonian = {}".format(Hc3))
# Out:
# Offset = 43.5
#
# Hamiltonian = SparsePauliOp(['IZI', 'ZII', 'IIZ', 'IZZ', 'ZIZ', 'ZZI'],
#               coeffs=[-3.5+0.j, -4. +0.j, -1.5+0.j, -4. +0.j,  2.5+0.j,  3. +0.j])

# %%
formatted_h = " + ".join([f"{c.real:.3f}{s}" for s, c in Hc3.label_iter()])
print(formatted_h)
# Out:
# -3.500IZI + -4.000ZII + -1.500IIZ + -4.000IZZ + 2.500ZIZ + 3.000ZZI

# %%
circuit3 = q.construct_circuit(Hc3, reps = 1)
print(circuit3)
fig = circuit3.draw('mpl') #Muestro el circuito
fig.savefig("figures/circuito_3cubits_p1.png", dpi = 150, bbox_inches = "tight")
fig
# Out:
#      ┌───┐┌───────────────┐                             ┌────────────┐»
# q_0: ┤ H ├┤ Rz((-3)*γ[0]) ├─■───────────────■───────────┤ Rx(2*β[0]) ├»
#      ├───┤├───────────────┤ │ZZ((-8)*γ[0])  │           └────────────┘»
# q_1: ┤ H ├┤ Rz((-7)*γ[0]) ├─■───────────────┼────────────■────────────»
#      ├───┤├───────────────┤                 │ZZ(5*γ[0])  │ZZ(6*γ[0])  »
# q_2: ┤ H ├┤ Rz((-8)*γ[0]) ├─────────────────■────────────■────────────»
#      └───┘└───────────────┘                                           »
# «
# «q_0: ──────────────
# «     ┌────────────┐
# «q_1: ┤ Rx(2*β[0]) ├
# «     ├────────────┤
# «q_2: ┤ Rx(2*β[0]) ├
# «     └────────────┘

# %%
x0 = np.asarray([0.0]*circuit3.num_parameters)

monitor, optParameters3 = q.qaoa_algorithm(circuit3, Hc3, x0)

# %%
print(optParameters3)
# Out:
# {'β[0]': np.float64(-0.5034916687001878), 'γ[0]': np.float64(0.10372812008473253)}

# %%
print(f'Total iteraciones = {monitor.iterations}')
print(f'Evolucion de evaluaciones = {monitor.evaluation}')
print(f'Evolucion de parametros = {monitor.parameters}')
# Out:
# Total iteraciones = 60
# Evolucion de evaluaciones = [np.float64(-6.974953359879105e-05), np.float64(-6.974953359879105e-05), np.float64(-0.0004184881190862494), np.float64(-0.001069394512198299), np.float64(-0.0040006540585020844), np.float64(-0.010550565092599988), np.float64(-0.03366236662722804), np.float64(-0.09112627233736295), np.float64(-0.26899575193249403), np.float64(-0.7144747620069518), np.float64(-1.8321693203996772), np.float64(-3.4992523592889837), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.8347914119365143), np.float64(-3.858271930511342), np.float64(-3.858271930511342), np.float64(-3.8912908708655696), np.float64(-3.911208274929298), np.float64(-4.0004892476480975), np.float64(-4.0004892476480975), np.float64(-4.146769903324421), np.float64(-4.265180790177032), np.float64(-4.6102452829885365), np.float64(-5.010749111937014), np.float64(-5.831851817863919), np.float64(-6.663555270221005), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.552883439389418), np.float64(-7.554298757658586), np.float64(-7.55505946985058), np.float64(-7.5556997325947695), np.float64(-7.5556997325947695), np.float64(-7.5556997325947695), np.float64(-7.555914747556697), np.float64(-7.555914747556697), np.float64(-7.555914747556697), np.float64(-7.555914785834791), np.float64(-7.555922074529812), np.float64(-7.555935163025097), np.float64(-7.555935163025097), np.float64(-7.555935163025097), np.float64(-7.555935163025097), np.float64(-7.555935163025097), np.float64(-7.555935163025097), np.float64(-7.555935205184914), np.float64(-7.555935205184914), np.float64(-7.555935205184914)]
# Evolucion de parametros = [array([-0.0005  ,  0.000375]), array([-0.0005  ,  0.000375]), array([-0.0015 ,  0.00075]), array([-0.002    ,  0.0014375]), array([-0.00425   ,  0.00253125]), array([-0.006375  ,  0.00445313]), array([-0.0119375 ,  0.00760156]), array([-0.01896875,  0.01301953]), array([-0.03360938,  0.02202539]), array([-0.05499219,  0.03736426]), array([-0.09496484,  0.06304541]), array([-0.1577168 ,  0.10656372]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.19768945,  0.13224487]), array([-0.20158447,  0.13375287]), array([-0.20158447,  0.13375287]), array([-0.19958368,  0.13143781]), array([-0.21163773,  0.13738835]), array([-0.21366316,  0.1357335 ]), array([-0.21366316,  0.1357335 ]), array([-0.2357951 ,  0.14134962]), array([-0.22275298,  0.1322566 ]), array([-0.26049581,  0.13894233]), array([-0.25328298,  0.12409916]), array([-0.32516221,  0.13004902]), array([-0.34667616,  0.10333762]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50119161,  0.10188164]), array([-0.50451699,  0.1051202 ]), array([-0.50832784,  0.10402008]), array([-0.50380701,  0.10322589]), array([-0.50380701,  0.10322589]), array([-0.50380701,  0.10322589]), array([-0.5037907 ,  0.10388662]), array([-0.5037907 ,  0.10388662]), array([-0.5037907 ,  0.10388662]), array([-0.50294585,  0.10362415]), array([-0.50339537,  0.10361584]), array([-0.50348065,  0.10375331]), array([-0.50348065,  0.10375331]), array([-0.50348065,  0.10375331]), array([-0.50348065,  0.10375331]), array([-0.50348065,  0.10375331]), array([-0.50348065,  0.10375331]), array([-0.50349167,  0.10372812]), array([-0.50349167,  0.10372812]), array([-0.50349167,  0.10372812])]

# %%
ncircuit3 = q.circ_asign_params(circuit3, optParameters3)
print(ncircuit3)
# Out:
#      ┌───┐┌──────────────┐                             ┌────────────┐»
# q_0: ┤ H ├┤ Rz(-0.31118) ├─■──────────────■────────────┤ Rx(-1.007) ├»
#      ├───┤├─────────────┬┘ │ZZ(-0.82982)  │            └────────────┘»
# q_1: ┤ H ├┤ Rz(-0.7261) ├──■──────────────┼─────────────■────────────»
#      ├───┤├─────────────┴┐                │ZZ(0.51864)  │ZZ(0.62237) »
# q_2: ┤ H ├┤ Rz(-0.82982) ├────────────────■─────────────■────────────»
#      └───┘└──────────────┘                                           »
# «
# «q_0: ──────────────
# «     ┌────────────┐
# «q_1: ┤ Rx(-1.007) ├
# «     ├────────────┤
# «q_2: ┤ Rx(-1.007) ├
# «     └────────────┘

# %%
results3 = q.sample_from_parameters(circuit3, list(optParameters3.values()), shots = 10_000)
print(len(results3))
for bitstring, count in results3.items():
    print(f"Bistring: {bitstring} -> Counts: {count}")
# Out:
# 8
# Bistring: 011 -> Counts: 3102
# Bistring: 000 -> Counts: 2843
# Bistring: 100 -> Counts: 2637
# Bistring: 001 -> Counts: 1045
# Bistring: 010 -> Counts: 249
# Bistring: 110 -> Counts: 48
# Bistring: 111 -> Counts: 42
# Bistring: 101 -> Counts: 34

# %%
fig = plot_histogram(results3)
fig.savefig("figures/3QubitCase_histograma.png", dpi = 150, bbox_inches = "tight")
fig

# %% [markdown]
# ## **3. Obtención de SR-Pairs**

# %%
nD3 = sl.integer_to_matrix(cvpResult.D)
print(nD3)
# Out:
# [[ 1 -2  2  3]
#  [-4  1  2 -2]
#  [-3  2  0  4]]

# %%
vnew3 = sl.bitstring2latticeVectors(nD3, results3.keys(), cvpResult.step_sign, cvpResult.b_op)
print(vnew3)
# Out:
# [[  3   5   0 241]
#  [  0   4   4 242]
#  [  3   2   4 238]
#  [ -1   6   2 239]
#  [  4   3   2 244]
#  [  7   1   2 240]
#  [  6   3   0 237]
#  [  2   4   2 235]]

# %%
distances3 = utils.get_distances(vnew3, cvpInstance.t)
for dist in distances3:
    print(np.linalg.norm(dist))
# Out:
# 5.916079783099616
# 6.0
# 5.744562646538029
# 6.48074069840786
# 6.708203932499369
# 7.3484692283495345
# 7.3484692283495345
# 7.0

# %%
nB3 = sl.integer_to_matrix(cvpInstance.B)
print(nB3)
# Out:
# [[ 1  0  0 22]
#  [ 0  1  0 35]
#  [ 0  0  2 51]]

# %%
uv_pairs3 = sl.vectors2uv_pairs(nB3, vnew3, threeQubit.get_n())
print(uv_pairs3)
# Out:
# [[1944 1]
#  [2025 1]
#  [1800 1]
#  [3645 2]
#  [2160 1]
#  [1920 1]
#  [1728 1]
#  [1620 1]]

# %%
sr_pairs3 = sl.uv_pairs2sr_pairs(uv_pairs3, threeQubit)
print(sr_pairs3)
# Out:
# [((1944, 1), -17), ((2025, 1), 64), ((1800, 1), -161), ((1920, 1), -41), ((1620, 1), -341)]

# %%
probs3 = utils.get_probs(results3.values(), shots = 10_000)

# %%
utils.prettyprint(vnew3, distances3, probs3, cvpResult.b_op, cvpResult.res_vector)
# Out:
# Vector más corto por algoritmo de Babai:
# b_op = [  0   4   4 242]
#
# El vector residual
# t - b_op = [ 0 -4 -4 -2]
#
# La distancia |t - b_op| = 6.000
#
# 0: Prob = 0.31020
# 	vnew = [  3   5   0 241] con distancia: 5.916
# 1: Prob = 0.28430
# 	vnew = [  0   4   4 242] con distancia: 6.000
# 2: Prob = 0.26370
# 	vnew = [  3   2   4 238] con distancia: 5.745
# 3: Prob = 0.10450
# 	vnew = [ -1   6   2 239] con distancia: 6.481
# 4: Prob = 0.02490
# 	vnew = [  4   3   2 244] con distancia: 6.708
# 5: Prob = 0.00480
# 	vnew = [  7   1   2 240] con distancia: 7.348
# 6: Prob = 0.00420
# 	vnew = [  6   3   0 237] con distancia: 7.348
# 7: Prob = 0.00340
# 	vnew = [  2   4   2 235] con distancia: 7.000

# %%
plt.figure(figsize=(8, 5))

# Creating the scatter plot
plt.scatter(distances3, probs3, color='blue', edgecolors='black', alpha=0.7)

# Adding labels and title
plt.xlabel('Distance')
plt.ylabel('Probability')
plt.title('Probability vs. Distance')

# Setting y-axis limit since you mentioned probs are <= 0.2
plt.ylim(0, 0.70) 

plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig("figures/3QubitCase_ProbsDistances.png", dpi=150, bbox_inches="tight")
plt.show()
