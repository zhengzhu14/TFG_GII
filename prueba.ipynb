# %%
# %load_ext autoreload
# %autoreload 2

from Crypto.Util import number
import random

from modules import utils

import numpy as np

# %%
np.random.seed(99)

print(np.random.randint(1, 10))
# Out:
# 2
