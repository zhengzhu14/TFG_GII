# %% [markdown]
# # **Evaluación de diferentes métodos de optimización clásica**

# %%
# %load_ext autoreload
# %autoreload 2

from modules import schnorr_lattice as sl
from modules import qaoa

from modules import utils

import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
seed = 99
q = 10
c = 3
l = 1

# %%
N = 48567227

# %%
cvp = sl.schnorrCVP(N, c, l, seed, verbose = True)
# Out:
# El numero de bits de N = 48567227 es m = 26
# La dimension del reticulo que vamos a tratar es n = 5
# La cota smooth que vamos a tomar: 50

# %%
instance = cvp.generate_cvp(q)
babresult = cvp.babai_algorithm(instance, 0.75)

qubo = qaoa.define_qubo(babresult.D, babresult.res_vector, babresult.step_sign, cvp.n)

Hc, offset = qaoa.define_hamiltonian(qubo)

circuit = qaoa.construct_circuit(Hc, reps = 1)
print(f'Offset = {offset}')
print(f'Hamiltonian = \n{Hc}')
# Out:
# B =
# [ 2 0 0 0 0  693 ]
# [ 0 1 0 0 0 1099 ]
# [ 0 0 3 0 0 1609 ]
# [ 0 0 0 2 0 1946 ]
# [ 0 0 0 0 1 2398 ]
# t =
# (0, 0, 0, 0, 0, 17698)
# Offset = 182.5
# Hamiltonian =
# SparsePauliOp(['IIIIZ', 'IIZII', 'ZIIII', 'IIIZI', 'IZIII', 'IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'],
#               coeffs=[-33.5+0.j, -11. +0.j, -29.5+0.j, -20. +0.j, -50. +0.j,   7. +0.j,
#  -10.5+0.j,  12. +0.j,   9.5+0.j,  -4.5+0.j,  15. +0.j,  -9. +0.j,
#    1. +0.j,  -4.5+0.j,   0.5+0.j])

# %% [markdown]
# ## Resolución con Nelder-Mead

# %%
mon1, result1 = qaoa.qaoa_algorithm(circuit, Hc)

for i, evals in enumerate(mon1.evaluation):
    print(f'{i} Evaluacion = {evals} \tAngulos = {mon1.parameters[i]}')
# Out:
# 0 Evaluacion = -0.004869510072088305 	Angulos = [ 0.000375 -0.0005  ]
# 1 Evaluacion = -0.004869510072088305 	Angulos = [ 0.000375 -0.0005  ]
# 2 Evaluacion = -0.02909822258680001 	Angulos = [ 0.00075 -0.0015 ]
# 3 Evaluacion = -0.07409538061090916 	Angulos = [ 0.0014375 -0.002    ]
# 4 Evaluacion = -0.2693880210470418 	Angulos = [ 0.00253125 -0.00425   ]
# 5 Evaluacion = -0.6785138926263258 	Angulos = [ 0.00445313 -0.006375  ]
# 6 Evaluacion = -1.7507883802280235 	Angulos = [ 0.00760156 -0.0119375 ]
# 7 Evaluacion = -2.935451948581919 	Angulos = [ 0.01301953 -0.01896875]
# 8 Evaluacion = -2.935451948581919 	Angulos = [ 0.01301953 -0.01896875]
# 9 Evaluacion = -2.935451948581919 	Angulos = [ 0.01301953 -0.01896875]
# 10 Evaluacion = -2.935451948581919 	Angulos = [ 0.01301953 -0.01896875]
# 11 Evaluacion = -2.935451948581919 	Angulos = [ 0.01301953 -0.01896875]
# 12 Evaluacion = -3.082876849065521 	Angulos = [ 0.01350391 -0.01859375]
# 13 Evaluacion = -3.082876849065521 	Angulos = [ 0.01350391 -0.01859375]
# 14 Evaluacion = -3.2513201391272055 	Angulos = [ 0.01526367 -0.02032813]
# 15 Evaluacion = -3.5143543987537798 	Angulos = [ 0.01508887 -0.01788281]
# 16 Evaluacion = -3.978148427420418 	Angulos = [ 0.018521   -0.02012891]
# 17 Evaluacion = -4.759599717724148 	Angulos = [ 0.01988745 -0.01636133]
# 18 Evaluacion = -6.15811924756759 	Angulos = [ 0.02743494 -0.01896973]
# 19 Evaluacion = -7.932579927707833 	Angulos = [ 0.03394159 -0.01273877]
# 20 Evaluacion = -12.465778547994002 	Angulos = [ 0.05228989 -0.01484009]
# 21 Evaluacion = -12.465778547994002 	Angulos = [ 0.05228989 -0.01484009]
# 22 Evaluacion = -19.84781287134374 	Angulos = [ 0.09874646 -0.00969629]
# 23 Evaluacion = -23.14266605687674 	Angulos = [ 0.10896144 -0.0195863 ]
# 24 Evaluacion = -45.20658172584669 	Angulos = [ 0.20698208 -0.01424371]
# 25 Evaluacion = -45.20658172584669 	Angulos = [ 0.20698208 -0.01424371]
# 26 Evaluacion = -72.78794327185821 	Angulos = [ 0.41834583 -0.01839355]
# 27 Evaluacion = -72.78794327185821 	Angulos = [ 0.41834583 -0.01839355]
# 28 Evaluacion = -82.97494890476723 	Angulos = [ 0.61949459 -0.01265338]
# 29 Evaluacion = -82.97494890476723 	Angulos = [ 0.61949459 -0.01265338]
# 30 Evaluacion = -82.97494890476723 	Angulos = [ 0.61949459 -0.01265338]
# 31 Evaluacion = -84.27773857455591 	Angulos = [ 0.67744302 -0.01863585]
# 32 Evaluacion = -84.81638835687926 	Angulos = [ 0.73966357 -0.01622392]
# 33 Evaluacion = -85.85152421885985 	Angulos = [ 0.66402394 -0.01504163]
# 34 Evaluacion = -85.85152421885985 	Angulos = [ 0.66402394 -0.01504163]
# 35 Evaluacion = -85.8641696892144 	Angulos = [ 0.61400376 -0.01595203]
# 36 Evaluacion = -86.04413689407292 	Angulos = [ 0.66432862 -0.01631557]
# 37 Evaluacion = -86.08499883014245 	Angulos = [ 0.65159507 -0.01558772]
# 38 Evaluacion = -86.08499883014245 	Angulos = [ 0.65159507 -0.01558772]
# 39 Evaluacion = -86.105095838473 	Angulos = [ 0.65405878 -0.01604267]
# 40 Evaluacion = -86.10554792551048 	Angulos = [ 0.64440486 -0.01588351]
# 41 Evaluacion = -86.10816174065262 	Angulos = [ 0.65041344 -0.0157754 ]
# 42 Evaluacion = -86.11163866822162 	Angulos = [ 0.65073396 -0.01593607]
# 43 Evaluacion = -86.11163866822162 	Angulos = [ 0.65073396 -0.01593607]
# 44 Evaluacion = -86.11163866822162 	Angulos = [ 0.65073396 -0.01593607]
# 45 Evaluacion = -86.11186594336466 	Angulos = [ 0.65162773 -0.01589658]
# 46 Evaluacion = -86.11200371315691 	Angulos = [ 0.65047169 -0.01587772]
# 47 Evaluacion = -86.11200371315691 	Angulos = [ 0.65047169 -0.01587772]
# 48 Evaluacion = -86.11207030776086 	Angulos = [ 0.65020878 -0.01589371]
# 49 Evaluacion = -86.11208130465512 	Angulos = [ 0.65061604 -0.01589866]
# 50 Evaluacion = -86.11208130465512 	Angulos = [ 0.65061604 -0.01589866]
# 51 Evaluacion = -86.1120818657747 	Angulos = [ 0.65042723 -0.01589157]
# 52 Evaluacion = -86.11208233581416 	Angulos = [ 0.65036521 -0.01589441]
# 53 Evaluacion = -86.11208577070312 	Angulos = [ 0.65050613 -0.01589583]
# 54 Evaluacion = -86.11208577070312 	Angulos = [ 0.65050613 -0.01589583]
# 55 Evaluacion = -86.11208577070312 	Angulos = [ 0.65050613 -0.01589583]
# 56 Evaluacion = -86.11208577070312 	Angulos = [ 0.65050613 -0.01589583]

# %%
print(result1)
# Out:
# {'β[0]': np.float64(0.6505061267065428), 'γ[0]': np.float64(-0.01589582783491532)}

# %% [markdown]
# ## Resolución con Cobyla

# %%
mon2, result2 = qaoa.qaoa_algorithm(circuit, Hc, min_method = "COBYLA")

for i, evals in enumerate(mon2.evaluation):
    print(f'{i} Evaluacion = {evals} \tAngulos = {mon2.parameters[i]}')
# Out:
# 0 Evaluacion = -2.844252611211573e-14 	Angulos = [0. 1.]
# 1 Evaluacion = -2.917978358940587e-14 	Angulos = [-2.77555756e-16  1.12500000e+00]
# 2 Evaluacion = -3.526901663645345 	Angulos = [-0.25   1.125]
# 3 Evaluacion = -6.814504267209856 	Angulos = [-0.75   1.125]
# 4 Evaluacion = -6.814504267209856 	Angulos = [-0.75   1.125]
# 5 Evaluacion = -6.814504267209856 	Angulos = [-0.75   1.125]
# 6 Evaluacion = -12.132372942822478 	Angulos = [-0.7353441   1.17280381]
# 7 Evaluacion = -12.132372942822478 	Angulos = [-0.7353441   1.17280381]
# 8 Evaluacion = -18.275858989538694 	Angulos = [-0.74248908  1.18306049]
# 9 Evaluacion = -18.63748405325118 	Angulos = [-0.74659175  1.1802025 ]
# 10 Evaluacion = -18.63748405325118 	Angulos = [-0.74659175  1.1802025 ]
# 11 Evaluacion = -18.711079025451912 	Angulos = [-0.74730624  1.18122816]
# 12 Evaluacion = -18.716606785651766 	Angulos = [-0.74979925  1.18141498]
# 13 Evaluacion = -18.71804242267418 	Angulos = [-0.75029875  1.18143746]
# 14 Evaluacion = -18.71804242267418 	Angulos = [-0.75029875  1.18143746]
# 15 Evaluacion = -18.719612880401485 	Angulos = [-0.75042333  1.18142726]
# 16 Evaluacion = -18.73240090160484 	Angulos = [-0.75042754  1.18117729]
# 17 Evaluacion = -18.73283464111426 	Angulos = [-0.7504683   1.18093064]
# 18 Evaluacion = -18.73378447691402 	Angulos = [-0.75056713  1.1809459 ]
# 19 Evaluacion = -18.734355561170094 	Angulos = [-0.75066711  1.18094417]
# 20 Evaluacion = -18.734355561170094 	Angulos = [-0.75066711  1.18094417]
# 21 Evaluacion = -18.735640271990775 	Angulos = [-0.7506901   1.18104149]
# 22 Evaluacion = -18.735640271990775 	Angulos = [-0.7506901   1.18104149]

# %%
print(result2)
# Out:
# {'β[0]': np.float64(-0.750690095602746), 'γ[0]': np.float64(1.181041494032295)}

# %%
res1 = list(result1.values())
x0 = [res1[0] - 0.001, res1[1] - 0.0001]

mon3, result3 = qaoa.qaoa_algorithm(circuit, Hc, x0, min_method = 'COBYLA')
for i, evals in enumerate(mon3.evaluation):
    print(f'{i} Evaluacion = {evals} \tAngulos = {mon3.parameters[i]}')
# Out:
# 0 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 1 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 2 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 3 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 4 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 5 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 6 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 7 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 8 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 9 Evaluacion = -86.10890169418516 	Angulos = [ 0.64950613 -0.01599583]
# 10 Evaluacion = -86.10943310957703 	Angulos = [ 0.6500061  -0.01599067]
# 11 Evaluacion = -86.10943310957703 	Angulos = [ 0.6500061  -0.01599067]
# 12 Evaluacion = -86.10943310957703 	Angulos = [ 0.6500061  -0.01599067]
# 13 Evaluacion = -86.10951307226674 	Angulos = [ 0.65005609 -0.01598953]
# 14 Evaluacion = -86.11204636120067 	Angulos = [ 0.65005512 -0.01588953]
# 15 Evaluacion = -86.11204636120067 	Angulos = [ 0.65005512 -0.01588953]

# %%
print(result3)
print(result1)
# Out:
# {'β[0]': np.float64(0.6500551204598171), 'γ[0]': np.float64(-0.015889530603923643)}
# {'β[0]': np.float64(0.6505061267065428), 'γ[0]': np.float64(-0.01589582783491532)}

# %% [markdown]
# ## Multistart optimizacion

# %%
k = 15
np.random.seed(seed)

# %%
angulos = []
iteraciones = []
for i in range(k):
    x = list(np.random.uniform(0, np.pi, 1)) + list(np.random.uniform(0, 2*np.pi, 1))
    print(x)
    mon, result = qaoa.qaoa_algorithm(circuit, Hc, x, min_method = 'COBYLA')
    angulos.append(list(result.values()))
    iteraciones.append(mon.iterations)
# Out:
# [np.float64(2.1120253809604304), np.float64(3.066687026860168)]
# [np.float64(2.5933695743249996), np.float64(0.19758348069743045)]
# [np.float64(2.538563828640507), np.float64(3.5538790603817163)]
# [np.float64(0.9350086554713481), np.float64(0.2933978649974532)]
# [np.float64(3.1121477606222143), np.float64(0.04288734557062449)]
# [np.float64(2.4183761221461553), np.float64(4.692076076852477)]
# [np.float64(1.1857593895686722), np.float64(3.104820011500726)]
# [np.float64(2.9183774441715222), np.float64(2.484711041098403)]
# [np.float64(3.0597739470353806), np.float64(3.294994834514473)]
# [np.float64(0.2940942061840354), np.float64(5.110167469398222)]
# [np.float64(0.6650336504695821), np.float64(3.4830572888371343)]
# [np.float64(0.9181905075684854), np.float64(5.1279736848383735)]
# [np.float64(2.6013724428549585), np.float64(1.392211686454752)]
# [np.float64(2.02580796133673), np.float64(0.5980437684462805)]
# [np.float64(1.2932782069019557), np.float64(0.6086223863417022)]

# %%
evaluaciones = qaoa.evaluate_params(circuit, Hc, angulos)
for i, (e , a) in enumerate(zip(evaluaciones, angulos)):
    print(f'{e:.4f} angulos = {a}, iteraciones = {iteraciones[i]}')
# Out:
# -31.5122 angulos = [np.float64(2.309809051433649), np.float64(3.535719899035735)], iteraciones = 902
# -16.5423 angulos = [np.float64(2.216390023362549), np.float64(-0.7122196363860611)], iteraciones = 113
# -25.1476 angulos = [np.float64(3.760446643224766), np.float64(3.561855754979068)], iteraciones = 917
# -30.2505 angulos = [np.float64(2.729601002023243), np.float64(-0.10927189664561865)], iteraciones = 310
# -21.0197 angulos = [np.float64(4.083457181972028), np.float64(1.1521657260534703)], iteraciones = 472
# -23.1672 angulos = [np.float64(2.19157935273951), np.float64(6.705614604149623)], iteraciones = 325
# -32.2284 angulos = [np.float64(2.295710435232734), np.float64(3.7989801392207276)], iteraciones = 371
# -39.3072 angulos = [np.float64(3.923662496490728), np.float64(3.483047287194807)], iteraciones = 17
# -26.7568 angulos = [np.float64(2.318967033872251), np.float64(4.479356660726301)], iteraciones = 646
# -17.4968 angulos = [np.float64(1.008379238713667), np.float64(5.10154798056459)], iteraciones = 524
# -38.8272 angulos = [np.float64(0.6867691269723655), np.float64(3.4829645213519185)], iteraciones = 117
# -21.4440 angulos = [np.float64(2.227519495154225), np.float64(5.1306967195016)], iteraciones = 747
# -25.7220 angulos = [np.float64(2.4322094582435376), np.float64(0.4953371953037373)], iteraciones = 22
# -22.8030 angulos = [np.float64(2.4750296386528223), np.float64(0.4217464481184762)], iteraciones = 72
# -11.7801 angulos = [np.float64(2.3991010275545577), np.float64(0.6027426398745745)], iteraciones = 19

# %% [markdown]
# ## Normalizando el Hamiltoniano

# %%
def normalize_hamiltonian (Hc):
    nHc = Hc.copy()
    norma = np.max(np.abs(nHc.coeffs))

    nHc.coeffs = nHc.coeffs / norma

    return nHc

# %%
nHc = normalize_hamiltonian(Hc)
print(nHc)
# Out:
# SparsePauliOp(['IIIIZ', 'IIZII', 'ZIIII', 'IIIZI', 'IZIII', 'IIIZZ', 'IIZIZ', 'IZIIZ', 'ZIIIZ', 'IIZZI', 'IZIZI', 'ZIIZI', 'IZZII', 'ZIZII', 'ZZIII'],
#               coeffs=[-0.67+0.j, -0.22+0.j, -0.59+0.j, -0.4 +0.j, -1.  +0.j,  0.14+0.j,
#  -0.21+0.j,  0.24+0.j,  0.19+0.j, -0.09+0.j,  0.3 +0.j, -0.18+0.j,
#   0.02+0.j, -0.09+0.j,  0.01+0.j])

# %%
ncircuit = qaoa.construct_circuit(nHc, reps = 1)

# %%
nmon, nresult = qaoa.qaoa_algorithm(ncircuit, Hc)

for i, evals in enumerate(nmon.evaluation):
    print(f'{i} Evaluacion = {evals} \tAngulos = {nmon.parameters[i]}')
# Out:
# 0 Evaluacion = -9.743995211731159e-05 	Angulos = [-0.0005    0.000375]
# 1 Evaluacion = -0.0003653993761986631 	Angulos = [-0.00075    0.0009375]
# 2 Evaluacion = -0.0014311398106655934 	Angulos = [-0.001875    0.00146875]
# 3 Evaluacion = -0.00436491733462205 	Angulos = [-0.0029375   0.00285937]
# 4 Evaluacion = -0.013720983607992891 	Angulos = [-0.00571875  0.00461719]
# 5 Evaluacion = -0.03971473264453092 	Angulos = [-0.00923438  0.00827734]
# 6 Evaluacion = -0.11713364119680475 	Angulos = [-0.01655469  0.01362305]
# 7 Evaluacion = -0.3338472050402101 	Angulos = [-0.02724609  0.02361621]
# 8 Evaluacion = -0.9602119819951399 	Angulos = [-0.04723242  0.0393042 ]
# 9 Evaluacion = -2.7062606494886428 	Angulos = [-0.0786084   0.06713452]
# 10 Evaluacion = -7.550486993596877 	Angulos = [-0.13426904  0.11242566]
# 11 Evaluacion = -20.007509218238233 	Angulos = [-0.22485132  0.19073187]
# 12 Evaluacion = -46.81482891974323 	Angulos = [-0.38146375  0.32046725]
# 13 Evaluacion = -78.27197439482846 	Angulos = [-0.64093451  0.54194737]
# 14 Evaluacion = -80.24081700806849 	Angulos = [-0.79754694  0.67168275]
# 15 Evaluacion = -80.24081700806849 	Angulos = [-0.79754694  0.67168275]
# 16 Evaluacion = -80.24081700806849 	Angulos = [-0.79754694  0.67168275]
# 17 Evaluacion = -80.75149451018673 	Angulos = [-0.72077523  0.60849488]
# 18 Evaluacion = -80.75149451018673 	Angulos = [-0.72077523  0.60849488]
# 19 Evaluacion = -80.80496905580304 	Angulos = [-0.75762658  0.638409  ]
# 20 Evaluacion = -80.82249897168543 	Angulos = [-0.76376461  0.64512826]
# 21 Evaluacion = -80.87452412049356 	Angulos = [-0.74073541  0.62513176]
# 22 Evaluacion = -80.99426618559872 	Angulos = [-0.74149687  0.62857202]
# 23 Evaluacion = -80.99426618559872 	Angulos = [-0.74149687  0.62857202]
# 24 Evaluacion = -81.05007585736914 	Angulos = [-0.75943505  0.64657964]
# 25 Evaluacion = -81.31094286849229 	Angulos = [-0.74651714  0.64074734]
# 26 Evaluacion = -81.31094286849229 	Angulos = [-0.74651714  0.64074734]
# 27 Evaluacion = -81.84169453474897 	Angulos = [-0.74758859  0.65609417]
# 28 Evaluacion = -81.84169453474897 	Angulos = [-0.74758859  0.65609417]
# 29 Evaluacion = -82.76559565452774 	Angulos = [-0.72282421  0.65977641]
# 30 Evaluacion = -83.1435096728185 	Angulos = [-0.74631838  0.69763276]
# 31 Evaluacion = -84.80016637848897 	Angulos = [-0.70853671  0.72392541]
# 32 Evaluacion = -84.80016637848897 	Angulos = [-0.70853671  0.72392541]
# 33 Evaluacion = -85.93048484895823 	Angulos = [-0.66821463  0.83329524]
# 34 Evaluacion = -86.1058694593567 	Angulos = [-0.64472046  0.79543889]
# 35 Evaluacion = -86.1058694593567 	Angulos = [-0.64472046  0.79543889]
# 36 Evaluacion = -86.1058694593567 	Angulos = [-0.64472046  0.79543889]
# 37 Evaluacion = -86.1058694593567 	Angulos = [-0.64472046  0.79543889]
# 38 Evaluacion = -86.1058694593567 	Angulos = [-0.64472046  0.79543889]
# 39 Evaluacion = -86.10747826510872 	Angulos = [-0.64840142  0.78843067]
# 40 Evaluacion = -86.10986058504469 	Angulos = [-0.65407407  0.79501723]
# 41 Evaluacion = -86.11092632978682 	Angulos = [-0.6479791   0.79358142]
# 42 Evaluacion = -86.11102305111405 	Angulos = [-0.65233917  0.79723365]
# 43 Evaluacion = -86.11163604354334 	Angulos = [-0.6521166   0.79521238]
# 44 Evaluacion = -86.11205174045134 	Angulos = [-0.65010349  0.79490222]
# 45 Evaluacion = -86.11205174045134 	Angulos = [-0.65010349  0.79490222]
# 46 Evaluacion = -86.11205174045134 	Angulos = [-0.65010349  0.79490222]
# 47 Evaluacion = -86.11205174045134 	Angulos = [-0.65010349  0.79490222]
# 48 Evaluacion = -86.11205970275874 	Angulos = [-0.65040445  0.79426556]
# 49 Evaluacion = -86.1120769246185 	Angulos = [-0.65065419  0.79456794]
# 50 Evaluacion = -86.11207912628265 	Angulos = [-0.65031641  0.79465949]
# 51 Evaluacion = -86.11208125553988 	Angulos = [-0.65056615  0.79496186]
# 52 Evaluacion = -86.11208499458908 	Angulos = [-0.65054773  0.79468931]
# 53 Evaluacion = -86.1120850077877 	Angulos = [-0.65043667  0.79474253]
# 54 Evaluacion = -86.11208517358752 	Angulos = [-0.65052918  0.79483889]
# 55 Evaluacion = -86.11208585378566 	Angulos = [-0.65051533  0.79474001]
# 56 Evaluacion = -86.11208585378566 	Angulos = [-0.65051533  0.79474001]

# %%
print(nresult)
# Out:
# {'β[0]': np.float64(-0.6505153290129466), 'γ[0]': np.float64(0.79474000872587)}

# %%
ncmon, ncresult = qaoa.qaoa_algorithm(ncircuit, Hc, min_method = 'COBYLA')
for i, evals in enumerate(ncmon.evaluation):
    print(f'{i} Evaluacion = {evals} \tAngulos = {ncmon.parameters[i]}')
# Out:
# 0 Evaluacion = -1.67765107361717e-14 	Angulos = [0. 0.]
# 1 Evaluacion = -1.67765107361717e-14 	Angulos = [0. 0.]
# 2 Evaluacion = -0.279889303060177 	Angulos = [ 0.01107171 -0.04875877]
# 3 Evaluacion = -2.6836270452625466 	Angulos = [ 0.11106192 -0.04735936]
# 4 Evaluacion = -7.132575473211711 	Angulos = [ 0.3110483  -0.04969382]
# 5 Evaluacion = -25.782354915908236 	Angulos = [ 0.70264446 -0.13125635]
# 6 Evaluacion = -80.7728078831463 	Angulos = [ 0.82955168 -0.92112631]
# 7 Evaluacion = -80.7728078831463 	Angulos = [ 0.82955168 -0.92112631]
# 8 Evaluacion = -82.6890081428915 	Angulos = [ 0.79877391 -0.82598048]
# 9 Evaluacion = -82.6890081428915 	Angulos = [ 0.79877391 -0.82598048]
# 10 Evaluacion = -85.64325703762177 	Angulos = [ 0.69899619 -0.83264435]
# 11 Evaluacion = -85.70767738408156 	Angulos = [ 0.60435417 -0.80035057]
# 12 Evaluacion = -85.70767738408156 	Angulos = [ 0.60435417 -0.80035057]
# 13 Evaluacion = -85.78724240664347 	Angulos = [ 0.61910294 -0.75257533]
# 14 Evaluacion = -85.82904228445969 	Angulos = [ 0.62409398 -0.75227621]
# 15 Evaluacion = -85.9334503106497 	Angulos = [ 0.63030883 -0.76011047]
# 16 Evaluacion = -86.05505568141321 	Angulos = [ 0.64647388 -0.7718872 ]
# 17 Evaluacion = -86.09521802866836 	Angulos = [ 0.64077798 -0.79105897]
# 18 Evaluacion = -86.10000244905493 	Angulos = [ 0.65699284 -0.80276702]
# 19 Evaluacion = -86.10000244905493 	Angulos = [ 0.65699284 -0.80276702]
# 20 Evaluacion = -86.10000244905493 	Angulos = [ 0.65699284 -0.80276702]
# 21 Evaluacion = -86.10000244905493 	Angulos = [ 0.65699284 -0.80276702]
# 22 Evaluacion = -86.10513464468474 	Angulos = [ 0.65542771 -0.80081756]
# 23 Evaluacion = -86.11093387670617 	Angulos = [ 0.65288296 -0.79651358]
# 24 Evaluacion = -86.11093387670617 	Angulos = [ 0.65288296 -0.79651358]
# 25 Evaluacion = -86.11174175332974 	Angulos = [ 0.65038303 -0.79649574]
# 26 Evaluacion = -86.11190817996007 	Angulos = [ 0.65038659 -0.79599575]
# 27 Evaluacion = -86.11191987731215 	Angulos = [ 0.64969516 -0.79527331]
# 28 Evaluacion = -86.11208064058764 	Angulos = [ 0.65040001 -0.79456396]
# 29 Evaluacion = -86.11208064058764 	Angulos = [ 0.65040001 -0.79456396]
# 30 Evaluacion = -86.11208198022373 	Angulos = [ 0.6503623  -0.79468314]
# 31 Evaluacion = -86.11208465957783 	Angulos = [ 0.65059296 -0.79477957]
# 32 Evaluacion = -86.11208465957783 	Angulos = [ 0.65059296 -0.79477957]
# 33 Evaluacion = -86.11208585676432 	Angulos = [ 0.6504942  -0.79476382]
# 34 Evaluacion = -86.11208585676432 	Angulos = [ 0.6504942  -0.79476382]

# %%
print(ncresult)
# Out:
# {'β[0]': np.float64(0.650494204432281), 'γ[0]': np.float64(-0.7947638234402519)}
